# %%
# !pip install rembg[gpu]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 47.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 KB 5.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 55.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 KB 3.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.8/33.8 MB 14.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 41.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 KB 9.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.7/47.7 KB 2.6 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 67.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 KB 3.0 MB/s eta 0:00:00
# ...

# %%
# !rembg --help
# Out:
# Usage: rembg [OPTIONS] COMMAND [ARGS]...
#
# Options:
#   --version  Show the version and exit.
#   --help     Show this message and exit.
#
# Commands:
#   i  for a file as input
#   p  for a folder as input
#   s  for a http server

# %%
# !git clone https://github.com/alexeygrigorev/clothing-dataset.git
# Out:
# Cloning into 'clothing-dataset'...
# remote: Enumerating objects: 5792, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 5792 (delta 13), reused 3 (delta 1), pack-reused 5766
# Receiving objects: 100% (5792/5792), 152.92 MiB | 26.22 MiB/s, done.
# Resolving deltas: 100% (14/14), done.
# Updating files: 100% (5759/5759), done.

# %%
import os
test_img = os.popen('ls clothing-dataset/images | shuf -n 1').read()
test_img = "clothing-dataset/images/" + test_img
test_img = os.path.abspath(test_img).replace('\n','')
os.environ['TEST_IMG'] = test_img
from IPython.display import Image
Image(filename=test_img)

# %%
# !rembg i $TEST_IMG output.png
# Out:
# ...
# 100%|████████████████████████████████████████| 176M/176M [00:00<00:00, 784GB/s]

# %%
Image(filename="output.png")

# %% [markdown]
# ---

# %%
from google.colab import drive
drive.mount('/content/drive')
# !unzip /content/drive/MyDrive/datasets/archive.zip

# %%
# !rembg p ./images_compressed ./without_bg
# Out:
# 100% 5762/5762 [2:36:26<00:00,  1.63s/it]

# %%
test_img = os.popen('ls without_bg | shuf -n 1').read()
test_img = "without_bg/" + test_img
test_img = os.path.abspath(test_img).replace('\n','')
Image(filename=test_img)

# %%
# !cp -r ./without_bg /content/drive/MyDrive/datasets/without_bg
